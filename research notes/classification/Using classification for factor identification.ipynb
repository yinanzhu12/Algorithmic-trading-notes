# %% [markdown]
# Here I code and discuss the example discussed in https://www.quantopian.com/posts/machine-learning-on-quantopian

# %%
from quantopian.research import run_pipeline
from quantopian.pipeline import Pipeline
from quantopian.pipeline.data.builtin import USEquityPricing
from quantopian.pipeline.data import morningstar
from quantopian.pipeline.factors import CustomFactor, SimpleMovingAverage, AverageDollarVolume, Returns, RSI,Latest
from quantopian.pipeline.classifiers.morningstar import Sector
from quantopian.pipeline.filters import QTradableStocksUS
from quantopian.pipeline.data.quandl import fred_usdontd156n as libor
from quantopian.pipeline.data.zacks import EarningsSurprises

import talib
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
from sklearn import linear_model, decomposition, ensemble, preprocessing

# %% [markdown]
# # Data creation and cleaning
#
# define a hell of factors

# %%
bs = morningstar.balance_sheet
cfs = morningstar.cash_flow_statement
is_ = morningstar.income_statement
or_ = morningstar.operation_ratios
er = morningstar.earnings_report
v = morningstar.valuation
vr = morningstar.valuation_ratios


def make_factors():
    def Asset_Growth_3M():
        return Returns(inputs=[bs.total_assets], window_length=63)

    def Asset_To_Equity_Ratio():
        return bs.total_assets.latest / bs.common_stock_equity.latest

    def Capex_To_Cashflows():
        return (cfs.capital_expenditure.latest * 4.) / \
            (cfs.free_cash_flow.latest * 4.)
        
    def EBITDA_Yield():
        return (is_.ebitda.latest * 4.) / \
            USEquityPricing.close.latest        

    def EBIT_To_Assets():
        return (is_.ebit.latest * 4.) / \
            bs.total_assets.latest
        
    def Earnings_Quality():
        return morningstar.cash_flow_statement.operating_cash_flow.latest / \
               EarningsSurprises.eps_act.latest
        
    def Return_On_Total_Invest_Capital():
        return or_.roic.latest
    
    class Mean_Reversion_1M(CustomFactor):
        inputs = [Returns(window_length=21)]
        window_length = 252

        def compute(self, today, assets, out, monthly_rets):
            out[:] = (monthly_rets[-1] - np.nanmean(monthly_rets, axis=0)) / \
                np.nanstd(monthly_rets, axis=0)
                
    class MACD_Signal_10d(CustomFactor):
        inputs = [USEquityPricing.close]
        window_length = 60

        def compute(self, today, assets, out, close):

            sig_lines = []

            for col in close.T:
                # get signal line only
                try:
                    _, signal_line, _ = talib.MACD(col, fastperiod=12,
                                                   slowperiod=26, signalperiod=10)
                    sig_lines.append(signal_line[-1])
                # if error calculating, return NaN
                except:
                    sig_lines.append(np.nan)
            out[:] = sig_lines 
            
    class Moneyflow_Volume_5d(CustomFactor):
        inputs = [USEquityPricing.close, USEquityPricing.volume]
        window_length = 5

        def compute(self, today, assets, out, close, volume):

            mfvs = []

            for col_c, col_v in zip(close.T, volume.T):

                # denominator
                denominator = np.dot(col_c, col_v)

                # numerator
                numerator = 0.
                for n, price in enumerate(col_c.tolist()):
                    if price > col_c[n - 1]:
                        numerator += price * col_v[n]
                    else:
                        numerator -= price * col_v[n]

                mfvs.append(numerator / denominator)
            out[:] = mfvs  
            
           
    def Net_Income_Margin():
        return or_.net_margin.latest           

    def Operating_Cashflows_To_Assets():
        return (cfs.operating_cash_flow.latest * 4.) / \
            bs.total_assets.latest

    def Price_Momentum_3M():
        return Returns(window_length=63)
    
    class Price_Oscillator(CustomFactor):
        inputs = [USEquityPricing.close]
        window_length = 252

        def compute(self, today, assets, out, close):
            four_week_period = close[-20:]
            out[:] = (np.nanmean(four_week_period, axis=0) /
                      np.nanmean(close, axis=0)) - 1.
    
    def Returns_39W():
        return Returns(window_length=215)
    
    class Trendline(CustomFactor):
        inputs = [USEquityPricing.close]
        window_length = 252

        # using MLE for speed
        def compute(self, today, assets, out, close):

            # prepare X matrix (x_is - x_bar)
            X = range(self.window_length)
            X_bar = np.nanmean(X)
            X_vector = X - X_bar
            X_matrix = np.tile(X_vector, (len(close.T), 1)).T

            # prepare Y matrix (y_is - y_bar)
            Y_bar = np.nanmean(close, axis=0)
            Y_bars = np.tile(Y_bar, (self.window_length, 1))
            Y_matrix = close - Y_bars

            # prepare variance of X
            X_var = np.nanvar(X)

            # multiply X matrix an Y matrix and sum (dot product)
            # then divide by variance of X
            # this gives the MLE of Beta
            out[:] = (np.sum((X_matrix * Y_matrix), axis=0) / X_var) / \
                (self.window_length)
        
    class Vol_3M(CustomFactor):
        inputs = [Returns(window_length=2)]
        window_length = 63

        def compute(self, today, assets, out, rets):
            out[:] = np.nanstd(rets, axis=0)
            
    def Working_Capital_To_Assets():
        return bs.working_capital.latest / bs.total_assets.latest
        
    all_factors = {
        'Asset Growth 3M': Asset_Growth_3M,
        'Asset to Equity Ratio': Asset_To_Equity_Ratio,
        'Capex to Cashflows': Capex_To_Cashflows,
        'EBIT to Assets': EBIT_To_Assets,
        'EBITDA Yield': EBITDA_Yield,        
        'Earnings Quality': Earnings_Quality,
        'MACD Signal Line': MACD_Signal_10d,
        'Mean Reversion 1M': Mean_Reversion_1M,
        'Moneyflow Volume 5D': Moneyflow_Volume_5d,
        'Net Income Margin': Net_Income_Margin,        
        'Operating Cashflows to Assets': Operating_Cashflows_To_Assets,
        'Price Momentum 3M': Price_Momentum_3M,
        'Price Oscillator': Price_Oscillator,
        'Return on Invest Capital': Return_On_Total_Invest_Capital,
        '39 Week Returns': Returns_39W,
        'Trendline': Trendline,
        'Vol 3M': Vol_3M,
        'Working Capital to Assets': Working_Capital_To_Assets,        
    }        
    
    return all_factors

# %% [markdown]
# add returns and whether the stock is in top/bottom 30% in returns in pipeline

# %%
def make_pipeline(n_fwd_days):
    pipe_screen=QTradableStocksUS()
    factors=make_factors()
    factor_ranks = {name: f().rank(mask=QTradableStocksUS()) for name, f in factors.iteritems()}
    returns=Returns(inputs=[USEquityPricing.open],mask=QTradableStocksUS(), window_length=n_fwd_days)
    pipe_columns=factor_ranks
    pipe_columns['returns']=returns
    pipe_columns['top_returns']=returns.percentile_between(70,100)
    pipe_columns['bottom_returns']=returns.percentile_between(0,30)
    return Pipeline(screen=pipe_screen,columns=pipe_columns)

# %%
start_date = "2017-01-01"
end_date = "2017-06-01"
n_fwd_days=5

# %%
output=run_pipeline(make_pipeline(n_fwd_days),start_date,end_date)
output.head()
# Out:
# /usr/local/lib/python2.7/dist-packages/numpy/lib/nanfunctions.py:1147: RuntimeWarning: Degrees of freedom <= 0 for slice.
#   warnings.warn("Degrees of freedom <= 0 for slice.", RuntimeWarning)
# /usr/local/lib/python2.7/dist-packages/numpy/lib/nanfunctions.py:675: RuntimeWarning: Mean of empty slice
#   warnings.warn("Mean of empty slice", RuntimeWarning)
#                                              39 Week Returns  Asset Growth 3M  \
# 2017-01-03 00:00:00+00:00 Equity(2 [ARNC])              65.0             46.0
#                           Equity(24 [AAPL])            995.0             47.0
#                           Equity(31 [ABAX])           1292.0             48.0
#                           Equity(41 [ARCB])           1430.0             49.0
#                           Equity(52 [ABM])            1261.0           1925.0
#
#                                              Asset to Equity Ratio  \
# 2017-01-03 00:00:00+00:00 Equity(2 [ARNC])                  1329.0
#                           Equity(24 [AAPL])                 1056.0
#                           Equity(31 [ABAX])                  139.0
#                           Equity(41 [ARCB])                  896.0
#                           Equity(52 [ABM])                   967.0
#
#                                              Capex to Cashflows  \
# 2017-01-03 00:00:00+00:00 Equity(2 [ARNC])                 19.0
#                           Equity(24 [AAPL])               670.0
#                           Equity(31 [ABAX])               293.0
#                           Equity(41 [ARCB])               186.0
#                           Equity(52 [ABM])               1854.0
#
#                                              EBIT to Assets  EBITDA Yield  \
# 2017-01-03 00:00:00+00:00 Equity(2 [ARNC])            736.0        1935.0
#                           Equity(24 [AAPL])          1560.0        1985.0
#                           Equity(31 [ABAX])          1581.0         302.0
#                           Equity(41 [ARCB])           911.0         929.0
#                           Equity(52 [ABM])            464.0         527.0
#
#                                              Earnings Quality  \
# 2017-01-03 00:00:00+00:00 Equity(2 [ARNC])                NaN
#                           Equity(24 [AAPL])            1966.0
#                           Equity(31 [ABAX])             378.0
#                           Equity(41 [ARCB])             751.0
#                           Equity(52 [ABM])              395.0
#
#                                              MACD Signal Line  \
# 2017-01-03 00:00:00+00:00 Equity(2 [ARNC])              183.0
#                           Equity(24 [AAPL])            1598.0
#                           Equity(31 [ABAX])             831.0
#                           Equity(41 [ARCB])            1288.0
#                           Equity(52 [ABM])              317.0
#
#                                              Mean Reversion 1M  \
# 2017-01-03 00:00:00+00:00 Equity(2 [ARNC])               638.0
#                           Equity(24 [AAPL])             1620.0
#                           Equity(31 [ABAX])             1255.0
#                           Equity(41 [ARCB])              151.0
#                           Equity(52 [ABM])                26.0
#
#                                              Moneyflow Volume 5D     ...       \
# 2017-01-03 00:00:00+00:00 Equity(2 [ARNC])                  10.0     ...
#                           Equity(24 [AAPL])                406.0     ...
#                           Equity(31 [ABAX])                602.0     ...
#                           Equity(41 [ARCB])                593.0     ...
#                           Equity(52 [ABM])                1674.0     ...
#
#                                              Operating Cashflows to Assets  \
# 2017-01-03 00:00:00+00:00 Equity(2 [ARNC])                           509.0
#                           Equity(24 [AAPL])                         1764.0
#                           Equity(31 [ABAX])                         1004.0
#                           Equity(41 [ARCB])                         1237.0
#                           Equity(52 [ABM])                           405.0
#
#                                              Price Momentum 3M  \
# 2017-01-03 00:00:00+00:00 Equity(2 [ARNC])                18.0
#                           Equity(24 [AAPL])              949.0
#                           Equity(31 [ABAX])              847.0
#                           Equity(41 [ARCB])             2006.0
#                           Equity(52 [ABM])               873.0
#
#                                              Price Oscillator  \
# 2017-01-03 00:00:00+00:00 Equity(2 [ARNC])               46.0
#                           Equity(24 [AAPL])             993.0
#                           Equity(31 [ABAX])            1000.0
#                           Equity(41 [ARCB])            1971.0
#                           Equity(52 [ABM])             1310.0
#
#                                              Return on Invest Capital  \
# 2017-01-03 00:00:00+00:00 Equity(2 [ARNC])                      707.0
#                           Equity(24 [AAPL])                    1714.0
#                           Equity(31 [ABAX])                    1797.0
#                           Equity(41 [ARCB])                     996.0
#                           Equity(52 [ABM])                      602.0
#
#                                              Trendline  Vol 3M  \
# 2017-01-03 00:00:00+00:00 Equity(2 [ARNC])       219.0  2001.0
#                           Equity(24 [AAPL])     1684.0    89.0
#                           Equity(31 [ABAX])     1198.0   990.0
#                           Equity(41 [ARCB])     1023.0  1589.0
#                           Equity(52 [ABM])      1495.0   731.0
#
#                                              Working Capital to Assets  \
# 2017-01-03 00:00:00+00:00 Equity(2 [ARNC])                       794.0
#                           Equity(24 [AAPL])                      719.0
#                           Equity(31 [ABAX])                     1713.0
#                           Equity(41 [ARCB])                      786.0
#                           Equity(52 [ABM])                      1030.0
#
#                                              bottom_returns   returns  \
# 2017-01-03 00:00:00+00:00 Equity(2 [ARNC])             True -0.061000
#                           Equity(24 [AAPL])           False  0.009170
#                           Equity(31 [ABAX])           False  0.035358
#                           Equity(41 [ARCB])           False -0.005272
#                           Equity(52 [ABM])            False  0.010654
#
#                                              top_returns
# 2017-01-03 00:00:00+00:00 Equity(2 [ARNC])         False
#                           Equity(24 [AAPL])         True
#                           Equity(31 [ABAX])         True
#                           Equity(41 [ARCB])        False
#                           Equity(52 [ABM])          True
#
# [5 rows x 21 columns]

# %%
feature=output.copy()
feature.drop(['returns','top_returns','bottom_returns'],axis=1,inplace=True)
feature
# Out:
#                                                   39 Week Returns  \
# 2017-01-03 00:00:00+00:00 Equity(2 [ARNC])                   65.0
#                           Equity(24 [AAPL])                 995.0
#                           Equity(31 [ABAX])                1292.0
#                           Equity(41 [ARCB])                1430.0
#                           Equity(52 [ABM])                 1261.0
#                           Equity(53 [ABMD])                1424.0
#                           Equity(62 [ABT])                  330.0
#                           Equity(64 [ABX])                  911.0
#                           Equity(67 [ADSK])                1516.0
#                           Equity(76 [TAP])                  829.0
#                           Equity(84 [ACET])                 382.0
#                           Equity(110 [ACXM])               1177.0
#                           Equity(114 [ADBE])                915.0
#                           Equity(122 [ADI])                1404.0
#                           Equity(128 [ADM])                1307.0
#                           Equity(154 [AEM])                1013.0
#                           Equity(161 [AEP])                 457.0
#                           Equity(166 [AES])                 981.0
#                           Equity(168 [AET])                 743.0
#                           Equity(185 [AFL])                 886.0
#                           Equity(197 [AGCO])               1002.0
#                           Equity(216 [HES])                1561.0
#                           Equity(239 [AIG])                1217.0
#                           Equity(247 [AIN])                1183.0
#                           Equity(253 [AIR])                1661.0
#                           Equity(266 [AJG])                1302.0
#                           Equity(270 [AKRX])                110.0
#                           Equity(289 [MATX])                213.0
#                           Equity(300 [ALK])                 963.0
#                           Equity(301 [ALKS])               1782.0
# ...                                                           ...
# 2017-06-01 00:00:00+00:00 Equity(49610 [SQ])               2070.0
#                           Equity(49615 [DLTH])              216.0
#                           Equity(49630 [CSRA])             1273.0
#                           Equity(49655 [TEAM])             1492.0
#                           Equity(49666 [AGR])               785.0
#                           Equity(49700 [FCE_A])             538.0
#                           Equity(49727 [GCP])              1001.0
#                           Equity(49736 [EDIT])               38.0
#                           Equity(49751 [AVXS])             2018.0
#                           Equity(49760 [WBT])               969.0
#                           Equity(49877 [PNK])              2014.0
#                           Equity(49883 [LSXM_K])           1459.0
#                           Equity(49891 [MGP])              1014.0
#                           Equity(49908 [RRR])               978.0
#                           Equity(49925 [NGVT])             1833.0
#                           Equity(49959 [SITE])             1659.0
#                           Equity(50002 [COTV])             1911.0
#                           Equity(50003 [USFD])             1353.0
#                           Equity(50004 [GMS])              1543.0
#                           Equity(50040 [ATKR])             1505.0
#                           Equity(50049 [FTV])              1540.0
#                           Equity(50070 [HTZ])                 2.0
#                           Equity(50077 [TWLO])               73.0
#                           Equity(50119 [TRTN])             2008.0
#                           Equity(50132 [APFH])             1989.0
#                           Equity(50138 [PI])               2062.0
#                           Equity(50143 [PTHN])             1734.0
#                           Equity(50181 [FHB])                 NaN
#                           Equity(50194 [MEDP])                NaN
#                           Equity(50242 [DVMT])                NaN
#
#                                                   Asset Growth 3M  \
# 2017-01-03 00:00:00+00:00 Equity(2 [ARNC])                   46.0
#                           Equity(24 [AAPL])                  47.0
#                           Equity(31 [ABAX])                  48.0
#                           Equity(41 [ARCB])                  49.0
#                           Equity(52 [ABM])                 1925.0
#                           Equity(53 [ABMD])                  50.0
#                           Equity(62 [ABT])                   51.0
#                           Equity(64 [ABX])                   52.0
#                           Equity(67 [ADSK])                  12.0
#                           Equity(76 [TAP])                   53.0
#                           Equity(84 [ACET])                  54.0
#                           Equity(110 [ACXM])                 55.0
#                           Equity(114 [ADBE])                 56.0
#                           Equity(122 [ADI])                1951.0
#                           Equity(128 [ADM])                  57.0
#                           Equity(154 [AEM])                  58.0
#                           Equity(161 [AEP])                  59.0
#                           Equity(166 [AES])                  60.0
#                           Equity(168 [AET])                  61.0
#                           Equity(185 [AFL])                  62.0
#                           Equity(197 [AGCO])                 63.0
#                           Equity(216 [HES])                  64.0
#                           Equity(239 [AIG])                  65.0
#                           Equity(247 [AIN])                  66.0
#                           Equity(253 [AIR])                1956.0
#                           Equity(266 [AJG])                  67.0
#                           Equity(270 [AKRX])                 68.0
#                           Equity(289 [MATX])                 69.0
#                           Equity(300 [ALK])                  70.0
#                           Equity(301 [ALKS])                 71.0
# ...                                                           ...
# 2017-06-01 00:00:00+00:00 Equity(49610 [SQ])               2005.0
#                           Equity(49615 [DLTH])              899.0
#                           Equity(49630 [CSRA])              915.0
#                           Equity(49655 [TEAM])             1943.0
#                           Equity(49666 [AGR])               986.0
#                           Equity(49700 [FCE_A])             484.0
#                           Equity(49727 [GCP])               441.0
#                           Equity(49736 [EDIT])             2040.0
#                           Equity(49751 [AVXS])               78.0
#                           Equity(49760 [WBT])              1647.0
#                           Equity(49877 [PNK])               348.0
#                           Equity(49883 [LSXM_K])             32.0
#                           Equity(49891 [MGP])               549.0
#                           Equity(49908 [RRR])               615.0
#                           Equity(49925 [NGVT])             1609.0
#                           Equity(49959 [SITE])             1988.0
#                           Equity(50002 [COTV])              910.0
#                           Equity(50003 [USFD])             1491.0
#                           Equity(50004 [GMS])               900.0
#                           Equity(50040 [ATKR])             1564.0
#                           Equity(50049 [FTV])              1065.0
#                           Equity(50070 [HTZ])              1493.0
#                           Equity(50077 [TWLO])             1674.0
#                           Equity(50119 [TRTN])              901.0
#                           Equity(50132 [APFH])             1496.0
#                           Equity(50138 [PI])                625.0
#                           Equity(50143 [PTHN])              902.0
#                           Equity(50181 [FHB])              1096.0
#                           Equity(50194 [MEDP])              402.0
#                           Equity(50242 [DVMT])              903.0
#
#                                                   Asset to Equity Ratio  \
# 2017-01-03 00:00:00+00:00 Equity(2 [ARNC])                       1329.0
#                           Equity(24 [AAPL])                      1056.0
#                           Equity(31 [ABAX])                       139.0
#                           Equity(41 [ARCB])                       896.0
#                           Equity(52 [ABM])                        967.0
#                           Equity(53 [ABMD])                       165.0
#                           Equity(62 [ABT])                        661.0
#                           Equity(64 [ABX])                       1395.0
#                           Equity(67 [ADSK])                      1576.0
#                           Equity(76 [TAP])                        908.0
#                           Equity(84 [ACET])                       550.0
#                           Equity(110 [ACXM])                      390.0
#                           Equity(114 [ADBE])                      497.0
#                           Equity(122 [ADI])                       382.0
#                           Equity(128 [ADM])                       923.0
#                           Equity(154 [AEM])                       437.0
#                           Equity(161 [AEP])                      1423.0
#                           Equity(166 [AES])                      1938.0
#                           Equity(168 [AET])                      1491.0
#                           Equity(185 [AFL])                      1722.0
#                           Equity(197 [AGCO])                     1100.0
#                           Equity(216 [HES])                       533.0
#                           Equity(239 [AIG])                      1684.0
#                           Equity(247 [AIN])                      1010.0
#                           Equity(253 [AIR])                       500.0
#                           Equity(266 [AJG])                      1275.0
#                           Equity(270 [AKRX])                     1005.0
#                           Equity(289 [MATX])                     1573.0
#                           Equity(300 [ALK])                      1274.0
#                           Equity(301 [ALKS])                      296.0
# ...                                                                 ...
# 2017-06-01 00:00:00+00:00 Equity(49610 [SQ])                     1084.0
#                           Equity(49615 [DLTH])                    301.0
#                           Equity(49630 [CSRA])                   2001.0
#                           Equity(49655 [TEAM])                    327.0
#                           Equity(49666 [AGR])                     801.0
#                           Equity(49700 [FCE_A])                  1043.0
#                           Equity(49727 [GCP])                      32.0
#                           Equity(49736 [EDIT])                    677.0
#                           Equity(49751 [AVXS])                    124.0
#                           Equity(49760 [WBT])                       5.0
#                           Equity(49877 [PNK])                      25.0
#                           Equity(49883 [LSXM_K])                 1155.0
#                           Equity(49891 [MGP])                    1796.0
#                           Equity(49908 [RRR])                    1916.0
#                           Equity(49925 [NGVT])                   1709.0
#                           Equity(49959 [SITE])                   1768.0
#                           Equity(50002 [COTV])                    795.0
#                           Equity(50003 [USFD])                   1457.0
#                           Equity(50004 [GMS])                    1215.0
#                           Equity(50040 [ATKR])                   1426.0
#                           Equity(50049 [FTV])                    1237.0
#                           Equity(50070 [HTZ])                    2024.0
#                           Equity(50077 [TWLO])                    215.0
#                           Equity(50119 [TRTN])                   1783.0
#                           Equity(50132 [APFH])                     44.0
#                           Equity(50138 [PI])                      253.0
#                           Equity(50143 [PTHN])                     29.0
#                           Equity(50181 [FHB])                    1842.0
#                           Equity(50194 [MEDP])                    396.0
#                           Equity(50242 [DVMT])                    754.0
#
#                                                   Capex to Cashflows  \
# 2017-01-03 00:00:00+00:00 Equity(2 [ARNC])                      19.0
#                           Equity(24 [AAPL])                    670.0
#                           Equity(31 [ABAX])                    293.0
#                           Equity(41 [ARCB])                    186.0
#                           Equity(52 [ABM])                    1854.0
#                           Equity(53 [ABMD])                    561.0
#                           Equity(62 [ABT])                     658.0
#                           Equity(64 [ABX])                     592.0
#                           Equity(67 [ADSK])                   1764.0
#                           Equity(76 [TAP])                     856.0
#                           Equity(84 [ACET])                    802.0
#                           Equity(110 [ACXM])                   437.0
#                           Equity(114 [ADBE])                  1070.0
#                           Equity(122 [ADI])                   1159.0
#                           Equity(128 [ADM])                    940.0
#                           Equity(154 [AEM])                    367.0
#                           Equity(161 [AEP])                    128.0
#                           Equity(166 [AES])                    182.0
#                           Equity(168 [AET])                   1347.0
#                           Equity(185 [AFL])                   1401.0
#                           Equity(197 [AGCO])                  1635.0
#                           Equity(216 [HES])                   1850.0
#                           Equity(239 [AIG])                   1349.0
#                           Equity(247 [AIN])                     91.0
#                           Equity(253 [AIR])                   1699.0
#                           Equity(266 [AJG])                    944.0
#                           Equity(270 [AKRX])                   516.0
#                           Equity(289 [MATX])                  1734.0
#                           Equity(300 [ALK])                    254.0
#                           Equity(301 [ALKS])                    83.0
# ...                                                              ...
# 2017-06-01 00:00:00+00:00 Equity(49610 [SQ])                   817.0
#                           Equity(49615 [DLTH])                 774.0
#                           Equity(49630 [CSRA])                 128.0
#                           Equity(49655 [TEAM])                1071.0
#                           Equity(49666 [AGR])                 1958.0
#                           Equity(49700 [FCE_A])               1863.0
#                           Equity(49727 [GCP])                 1618.0
#                           Equity(49736 [EDIT])                1237.0
#                           Equity(49751 [AVXS])                1507.0
#                           Equity(49760 [WBT])                 1417.0
#                           Equity(49877 [PNK])                   68.0
#                           Equity(49883 [LSXM_K])               735.0
#                           Equity(49891 [MGP])                 1278.0
#                           Equity(49908 [RRR])                  340.0
#                           Equity(49925 [NGVT])                1875.0
#                           Equity(49959 [SITE])                1381.0
#                           Equity(50002 [COTV])                 381.0
#                           Equity(50003 [USFD])                 220.0
#                           Equity(50004 [GMS])                 1100.0
#                           Equity(50040 [ATKR])                1577.0
#                           Equity(50049 [FTV])                  728.0
#                           Equity(50070 [HTZ])                 1749.0
#                           Equity(50077 [TWLO])                1784.0
#                           Equity(50119 [TRTN])                2011.0
#                           Equity(50132 [APFH])                 474.0
#                           Equity(50138 [PI])                  1406.0
#                           Equity(50143 [PTHN])                1680.0
#                           Equity(50181 [FHB])                 1215.0
#                           Equity(50194 [MEDP])                1687.0
#                           Equity(50242 [DVMT])                1625.0
#
#                                                   EBIT to Assets  \
# 2017-01-03 00:00:00+00:00 Equity(2 [ARNC])                 736.0
#                           Equity(24 [AAPL])               1560.0
#                           Equity(31 [ABAX])               1581.0
#                           Equity(41 [ARCB])                911.0
#                           Equity(52 [ABM])                 464.0
#                           Equity(53 [ABMD])               1371.0
#                           Equity(62 [ABT])                 287.0
#                           Equity(64 [ABX])                1314.0
#                           Equity(67 [ADSK])                154.0
#                           Equity(76 [TAP])                 759.0
#                           Equity(84 [ACET])                912.0
#                           Equity(110 [ACXM])               481.0
#                           Equity(114 [ADBE])              1368.0
#                           Equity(122 [ADI])               1638.0
#                           Equity(128 [ADM])                797.0
#                           Equity(154 [AEM])                839.0
#                           Equity(161 [AEP])                179.0
#                           Equity(166 [AES])                952.0
#                           Equity(168 [AET])                956.0
#                           Equity(185 [AFL])                519.0
#                           Equity(197 [AGCO])               545.0
#                           Equity(216 [HES])                187.0
#                           Equity(239 [AIG])                365.0
#                           Equity(247 [AIN])               1029.0
#                           Equity(253 [AIR])                776.0
#                           Equity(266 [AJG])                692.0
#                           Equity(270 [AKRX])              1627.0
#                           Equity(289 [MATX])              1131.0
#                           Equity(300 [ALK])               1655.0
#                           Equity(301 [ALKS])               125.0
# ...                                                          ...
# 2017-06-01 00:00:00+00:00 Equity(49610 [SQ])               226.0
#                           Equity(49615 [DLTH])            1872.0
#                           Equity(49630 [CSRA])             917.0
#                           Equity(49655 [TEAM])             174.0
#                           Equity(49666 [AGR])              838.0
#                           Equity(49700 [FCE_A])            553.0
#                           Equity(49727 [GCP])              406.0
#                           Equity(49736 [EDIT])              76.0
#                           Equity(49751 [AVXS])              40.0
#                           Equity(49760 [WBT])             1006.0
#                           Equity(49877 [PNK])             1399.0
#                           Equity(49883 [LSXM_K])           889.0
#                           Equity(49891 [MGP])              678.0
#                           Equity(49908 [RRR])             1358.0
#                           Equity(49925 [NGVT])            1671.0
#                           Equity(49959 [SITE])             198.0
#                           Equity(50002 [COTV])            1044.0
#                           Equity(50003 [USFD])             600.0
#                           Equity(50004 [GMS])              937.0
#                           Equity(50040 [ATKR])            1440.0
#                           Equity(50049 [FTV])             1562.0
#                           Equity(50070 [HTZ])              243.0
#                           Equity(50077 [TWLO])             131.0
#                           Equity(50119 [TRTN])             634.0
#                           Equity(50132 [APFH])            1696.0
#                           Equity(50138 [PI])               202.0
#                           Equity(50143 [PTHN])             943.0
#                           Equity(50181 [FHB])                NaN
#                           Equity(50194 [MEDP])            1007.0
#                           Equity(50242 [DVMT])              69.0
#
#                                                   EBITDA Yield  \
# 2017-01-03 00:00:00+00:00 Equity(2 [ARNC])              1935.0
#                           Equity(24 [AAPL])             1985.0
#                           Equity(31 [ABAX])              302.0
#                           Equity(41 [ARCB])              929.0
#                           Equity(52 [ABM])               527.0
#                           Equity(53 [ABMD])              262.0
#                           Equity(62 [ABT])              1585.0
#                           Equity(64 [ABX])              1964.0
#                           Equity(67 [ADSK])              117.0
#                           Equity(76 [TAP])              1303.0
#                           Equity(84 [ACET])              458.0
#                           Equity(110 [ACXM])             663.0
#                           Equity(114 [ADBE])            1376.0
#                           Equity(122 [ADI])             1486.0
#                           Equity(128 [ADM])             1812.0
#                           Equity(154 [AEM])             1530.0
#                           Equity(161 [AEP])               30.0
#                           Equity(166 [AES])             1971.0
#                           Equity(168 [AET])             1722.0
#                           Equity(185 [AFL])             1795.0
#                           Equity(197 [AGCO])            1051.0
#                           Equity(216 [HES])             1354.0
#                           Equity(239 [AIG])             1972.0
#                           Equity(247 [AIN])              634.0
#                           Equity(253 [AIR])              643.0
#                           Equity(266 [AJG])             1341.0
#                           Equity(270 [AKRX])            1428.0
#                           Equity(289 [MATX])            1001.0
#                           Equity(300 [ALK])             1485.0
#                           Equity(301 [ALKS])             148.0
# ...                                                        ...
# 2017-06-01 00:00:00+00:00 Equity(49610 [SQ])             179.0
#                           Equity(49615 [DLTH])           816.0
#                           Equity(49630 [CSRA])          1402.0
#                           Equity(49655 [TEAM])           193.0
#                           Equity(49666 [AGR])           1797.0
#                           Equity(49700 [FCE_A])         1512.0
#                           Equity(49727 [GCP])            393.0
#                           Equity(49736 [EDIT])            66.0
#                           Equity(49751 [AVXS])           159.0
#                           Equity(49760 [WBT])           1095.0
#                           Equity(49877 [PNK])           1673.0
#                           Equity(49883 [LSXM_K])        1744.0
#                           Equity(49891 [MGP])           1516.0
#                           Equity(49908 [RRR])           1540.0
#                           Equity(49925 [NGVT])           622.0
#                           Equity(49959 [SITE])           211.0
#                           Equity(50002 [COTV])           902.0
#                           Equity(50003 [USFD])          1556.0
#                           Equity(50004 [GMS])            794.0
#                           Equity(50040 [ATKR])          1076.0
#                           Equity(50049 [FTV])           1502.0
#                           Equity(50070 [HTZ])           2002.0
#                           Equity(50077 [TWLO])           157.0
#                           Equity(50119 [TRTN])          1362.0
#                           Equity(50132 [APFH])          1031.0
#                           Equity(50138 [PI])             216.0
#                           Equity(50143 [PTHN])          1043.0
#                           Equity(50181 [FHB])              NaN
#                           Equity(50194 [MEDP])           696.0
#                           Equity(50242 [DVMT])           900.0
#
#                                                   Earnings Quality  \
# 2017-01-03 00:00:00+00:00 Equity(2 [ARNC])                     NaN
#                           Equity(24 [AAPL])                 1966.0
#                           Equity(31 [ABAX])                  378.0
#                           Equity(41 [ARCB])                  751.0
#                           Equity(52 [ABM])                   395.0
#                           Equity(53 [ABMD])                  821.0
#                           Equity(62 [ABT])                  1886.0
#                           Equity(64 [ABX])                  1936.0
#                           Equity(67 [ADSK])                  258.0
#                           Equity(76 [TAP])                  1605.0
#                           Equity(84 [ACET])                  511.0
#                           Equity(110 [ACXM])                1542.0
#                           Equity(114 [ADBE])                1647.0
#                           Equity(122 [ADI])                 1557.0
#                           Equity(128 [ADM])                 1907.0
#                           Equity(154 [AEM])                 1794.0
#                           Equity(161 [AEP])                 1818.0
#                           Equity(166 [AES])                 1906.0
#                           Equity(168 [AET])                 1791.0
#                           Equity(185 [AFL])                 1678.0
#                           Equity(197 [AGCO])                 162.0
#                           Equity(216 [HES])                  116.0
#                           Equity(239 [AIG])                 1797.0
#                           Equity(247 [AIN])                  734.0
#                           Equity(253 [AIR])                  295.0
#                           Equity(266 [AJG])                 1414.0
#                           Equity(270 [AKRX])                 942.0
#                           Equity(289 [MATX])                 357.0
#                           Equity(300 [ALK])                 1048.0
#                           Equity(301 [ALKS])                 204.0
# ...                                                            ...
# 2017-06-01 00:00:00+00:00 Equity(49610 [SQ])                  53.0
#                           Equity(49615 [DLTH])              1041.0
#                           Equity(49630 [CSRA])              1017.0
#                           Equity(49655 [TEAM])                54.0
#                           Equity(49666 [AGR])               1732.0
#                           Equity(49700 [FCE_A])             1553.0
#                           Equity(49727 [GCP])               1395.0
#                           Equity(49736 [EDIT])               256.0
#                           Equity(49751 [AVXS])               555.0
#                           Equity(49760 [WBT])                100.0
#                           Equity(49877 [PNK])                884.0
#                           Equity(49883 [LSXM_K])            1812.0
#                           Equity(49891 [MGP])               1727.0
#                           Equity(49908 [RRR])               1520.0
#                           Equity(49925 [NGVT])               473.0
#                           Equity(49959 [SITE])              1338.0
#                           Equity(50002 [COTV])               897.0
#                           Equity(50003 [USFD])              1767.0
#                           Equity(50004 [GMS])               1047.0
#                           Equity(50040 [ATKR])               331.0
#                           Equity(50049 [FTV])               1427.0
#                           Equity(50070 [HTZ])                146.0
#                           Equity(50077 [TWLO])               353.0
#                           Equity(50119 [TRTN])              1305.0
#                           Equity(50132 [APFH])              1107.0
#                           Equity(50138 [PI])                1414.0
#                           Equity(50143 [PTHN])               240.0
#                           Equity(50181 [FHB])               1194.0
#                           Equity(50194 [MEDP])               400.0
#                           Equity(50242 [DVMT])               188.0
#
#                                                   MACD Signal Line  \
# 2017-01-03 00:00:00+00:00 Equity(2 [ARNC])                   183.0
#                           Equity(24 [AAPL])                 1598.0
#                           Equity(31 [ABAX])                  831.0
#                           Equity(41 [ARCB])                 1288.0
#                           Equity(52 [ABM])                   317.0
#                           Equity(53 [ABMD])                  311.0
#                           Equity(62 [ABT])                   279.0
#                           Equity(64 [ABX])                   322.0
#                           Equity(67 [ADSK])                 1233.0
#                           Equity(76 [TAP])                   100.0
#                           Equity(84 [ACET])                 1216.0
#                           Equity(110 [ACXM])                 849.0
#                           Equity(114 [ADBE])                 361.0
#                           Equity(122 [ADI])                 1751.0
#                           Equity(128 [ADM])                 1189.0
#                           Equity(154 [AEM])                   78.0
#                           Equity(161 [AEP])                 1229.0
#                           Equity(166 [AES])                  636.0
#                           Equity(168 [AET])                 1522.0
#                           Equity(185 [AFL])                  400.0
#                           Equity(197 [AGCO])                1586.0
#                           Equity(216 [HES])                 1978.0
#                           Equity(239 [AIG])                 1512.0
#                           Equity(247 [AIN])                 1365.0
#                           Equity(253 [AIR])                  630.0
#                           Equity(266 [AJG])                 1076.0
#                           Equity(270 [AKRX])                 213.0
#                           Equity(289 [MATX])                 176.0
#                           Equity(300 [ALK])                 1999.0
#                           Equity(301 [ALKS])                1157.0
# ...                                                            ...
# 2017-06-01 00:00:00+00:00 Equity(49610 [SQ])                1785.0
#                           Equity(49615 [DLTH])               810.0
#                           Equity(49630 [CSRA])              1309.0
#                           Equity(49655 [TEAM])              1796.0
#                           Equity(49666 [AGR])               1482.0
#                           Equity(49700 [FCE_A])             1168.0
#                           Equity(49727 [GCP])                385.0
#                           Equity(49736 [EDIT])               204.0
#                           Equity(49751 [AVXS])               194.0
#                           Equity(49760 [WBT])               1020.0
#                           Equity(49877 [PNK])                968.0
#                           Equity(49883 [LSXM_K])            1293.0
#                           Equity(49891 [MGP])               1263.0
#                           Equity(49908 [RRR])               1424.0
#                           Equity(49925 [NGVT])               472.0
#                           Equity(49959 [SITE])              1782.0
#                           Equity(50002 [COTV])               531.0
#                           Equity(50003 [USFD])              1507.0
#                           Equity(50004 [GMS])                500.0
#                           Equity(50040 [ATKR])               183.0
#                           Equity(50049 [FTV])               1578.0
#                           Equity(50070 [HTZ])                 64.0
#                           Equity(50077 [TWLO])               133.0
#                           Equity(50119 [TRTN])              1451.0
#                           Equity(50132 [APFH])              1895.0
#                           Equity(50138 [PI])                2013.0
#                           Equity(50143 [PTHN])              1964.0
#                           Equity(50181 [FHB])                564.0
#                           Equity(50194 [MEDP])               514.0
#                           Equity(50242 [DVMT])              1630.0
#
#                                                   Mean Reversion 1M  \
# 2017-01-03 00:00:00+00:00 Equity(2 [ARNC])                    638.0
#                           Equity(24 [AAPL])                  1620.0
#                           Equity(31 [ABAX])                  1255.0
#                           Equity(41 [ARCB])                   151.0
#                           Equity(52 [ABM])                     26.0
#                           Equity(53 [ABMD])                  1200.0
#                           Equity(62 [ABT])                   1362.0
#                           Equity(64 [ABX])                    854.0
#                           Equity(67 [ADSK])                  1431.0
#                           Equity(76 [TAP])                   1410.0
#                           Equity(84 [ACET])                  1766.0
#                           Equity(110 [ACXM])                 1145.0
#                           Equity(114 [ADBE])                 1392.0
#                           Equity(122 [ADI])                  1373.0
#                           Equity(128 [ADM])                  1034.0
#                           Equity(154 [AEM])                  1002.0
#                           Equity(161 [AEP])                  1993.0
#                           Equity(166 [AES])                  1416.0
#                           Equity(168 [AET])                    37.0
#                           Equity(185 [AFL])                   328.0
#                           Equity(197 [AGCO])                  858.0
#                           Equity(216 [HES])                  1581.0
#                           Equity(239 [AIG])                  1212.0
#                           Equity(247 [AIN])                   521.0
#                           Equity(253 [AIR])                    39.0
#                           Equity(266 [AJG])                  1451.0
#                           Equity(270 [AKRX])                 1741.0
#                           Equity(289 [MATX])                  543.0
#                           Equity(300 [ALK])                  1515.0
#                           Equity(301 [ALKS])                  965.0
# ...                                                             ...
# 2017-06-01 00:00:00+00:00 Equity(49610 [SQ])                 2016.0
#                           Equity(49615 [DLTH])                797.0
#                           Equity(49630 [CSRA])               1484.0
#                           Equity(49655 [TEAM])               1164.0
#                           Equity(49666 [AGR])                1670.0
#                           Equity(49700 [FCE_A])              1339.0
#                           Equity(49727 [GCP])                 203.0
#                           Equity(49736 [EDIT])                111.0
#                           Equity(49751 [AVXS])                447.0
#                           Equity(49760 [WBT])                 233.0
#                           Equity(49877 [PNK])                 147.0
#                           Equity(49883 [LSXM_K])             2055.0
#                           Equity(49891 [MGP])                 620.0
#                           Equity(49908 [RRR])                1574.0
#                           Equity(49925 [NGVT])                284.0
#                           Equity(49959 [SITE])               1680.0
#                           Equity(50002 [COTV])                238.0
#                           Equity(50003 [USFD])               1824.0
#                           Equity(50004 [GMS])                 150.0
#                           Equity(50040 [ATKR])                  8.0
#                           Equity(50049 [FTV])                1003.0
#                           Equity(50070 [HTZ])                 213.0
#                           Equity(50077 [TWLO])                289.0
#                           Equity(50119 [TRTN])                844.0
#                           Equity(50132 [APFH])                802.0
#                           Equity(50138 [PI])                 1601.0
#                           Equity(50143 [PTHN])               2056.0
#                           Equity(50181 [FHB])                 501.0
#                           Equity(50194 [MEDP])               2062.0
#                           Equity(50242 [DVMT])               1251.0
#
#                                                   Moneyflow Volume 5D  \
# 2017-01-03 00:00:00+00:00 Equity(2 [ARNC])                       10.0
#                           Equity(24 [AAPL])                     406.0
#                           Equity(31 [ABAX])                     602.0
#                           Equity(41 [ARCB])                     593.0
#                           Equity(52 [ABM])                     1674.0
#                           Equity(53 [ABMD])                    1049.0
#                           Equity(62 [ABT])                     1868.0
#                           Equity(64 [ABX])                     1808.0
#                           Equity(67 [ADSK])                     188.0
#                           Equity(76 [TAP])                      731.0
#                           Equity(84 [ACET])                    1936.0
#                           Equity(110 [ACXM])                   1517.0
#                           Equity(114 [ADBE])                     55.0
#                           Equity(122 [ADI])                     906.0
#                           Equity(128 [ADM])                    1551.0
#                           Equity(154 [AEM])                    1721.0
#                           Equity(161 [AEP])                     781.0
#                           Equity(166 [AES])                    1718.0
#                           Equity(168 [AET])                     655.0
#                           Equity(185 [AFL])                    1458.0
#                           Equity(197 [AGCO])                      6.0
#                           Equity(216 [HES])                     845.0
#                           Equity(239 [AIG])                     314.0
#                           Equity(247 [AIN])                     831.0
#                           Equity(253 [AIR])                     705.0
#                           Equity(266 [AJG])                    1921.0
#                           Equity(270 [AKRX])                    376.0
#                           Equity(289 [MATX])                    651.0
#                           Equity(300 [ALK])                    1482.0
#                           Equity(301 [ALKS])                   1601.0
# ...                                                               ...
# 2017-06-01 00:00:00+00:00 Equity(49610 [SQ])                   1806.0
#                           Equity(49615 [DLTH])                 1213.0
#                           Equity(49630 [CSRA])                  284.0
#                           Equity(49655 [TEAM])                 1985.0
#                           Equity(49666 [AGR])                  1987.0
#                           Equity(49700 [FCE_A])                1589.0
#                           Equity(49727 [GCP])                   785.0
#                           Equity(49736 [EDIT])                    3.0
#                           Equity(49751 [AVXS])                 1927.0
#                           Equity(49760 [WBT])                    56.0
#                           Equity(49877 [PNK])                  1371.0
#                           Equity(49883 [LSXM_K])               1880.0
#                           Equity(49891 [MGP])                  1347.0
#                           Equity(49908 [RRR])                   624.0
#                           Equity(49925 [NGVT])                  275.0
#                           Equity(49959 [SITE])                 1368.0
#                           Equity(50002 [COTV])                 1339.0
#                           Equity(50003 [USFD])                 2067.0
#                           Equity(50004 [GMS])                   686.0
#                           Equity(50040 [ATKR])                  838.0
#                           Equity(50049 [FTV])                   253.0
#                           Equity(50070 [HTZ])                   650.0
#                           Equity(50077 [TWLO])                  224.0
#                           Equity(50119 [TRTN])                 1325.0
#                           Equity(50132 [APFH])                  587.0
#                           Equity(50138 [PI])                   1819.0
#                           Equity(50143 [PTHN])                  890.0
#                           Equity(50181 [FHB])                   867.0
#                           Equity(50194 [MEDP])                 2077.0
#                           Equity(50242 [DVMT])                 1747.0
#
#                                                   Net Income Margin  \
# 2017-01-03 00:00:00+00:00 Equity(2 [ARNC])                    629.0
#                           Equity(24 [AAPL])                  1686.0
#                           Equity(31 [ABAX])                  1695.0
#                           Equity(41 [ARCB])                   545.0
#                           Equity(52 [ABM])                    464.0
#                           Equity(53 [ABMD])                  1173.0
#                           Equity(62 [ABT])                    275.0
#                           Equity(64 [ABX])                   1082.0
#                           Equity(67 [ADSK])                   138.0
#                           Equity(76 [TAP])                   1749.0
#                           Equity(84 [ACET])                   683.0
#                           Equity(110 [ACXM])                  665.0
#                           Equity(114 [ADBE])                 1669.0
#                           Equity(122 [ADI])                  1880.0
#                           Equity(128 [ADM])                   568.0
#                           Equity(154 [AEM])                  1121.0
#                           Equity(161 [AEP])                   181.0
#                           Equity(166 [AES])                   830.0
#                           Equity(168 [AET])                   722.0
#                           Equity(185 [AFL])                  1331.0
#                           Equity(197 [AGCO])                  578.0
#                           Equity(216 [HES])                   136.0
#                           Equity(239 [AIG])                   700.0
#                           Equity(247 [AIN])                  1012.0
#                           Equity(253 [AIR])                   633.0
#                           Equity(266 [AJG])                  1141.0
#                           Equity(270 [AKRX])                 1618.0
#                           Equity(289 [MATX])                  838.0
#                           Equity(300 [ALK])                  1604.0
#                           Equity(301 [ALKS])                  127.0
# ...                                                             ...
# 2017-06-01 00:00:00+00:00 Equity(49610 [SQ])                  327.0
#                           Equity(49615 [DLTH])               1149.0
#                           Equity(49630 [CSRA])                659.0
#                           Equity(49655 [TEAM])                207.0
#                           Equity(49666 [AGR])                1516.0
#                           Equity(49700 [FCE_A])              1699.0
#                           Equity(49727 [GCP])                 241.0
#                           Equity(49736 [EDIT])                 16.0
#                           Equity(49751 [AVXS])                  NaN
#                           Equity(49760 [WBT])                 544.0
#                           Equity(49877 [PNK])                 631.0
#                           Equity(49883 [LSXM_K])             1285.0
#                           Equity(49891 [MGP])                 998.0
#                           Equity(49908 [RRR])                 845.0
#                           Equity(49925 [NGVT])               1216.0
#                           Equity(49959 [SITE])                332.0
#                           Equity(50002 [COTV])               1635.0
#                           Equity(50003 [USFD])                453.0
#                           Equity(50004 [GMS])                 538.0
#                           Equity(50040 [ATKR])                878.0
#                           Equity(50049 [FTV])                1490.0
#                           Equity(50070 [HTZ])                 204.0
#                           Equity(50077 [TWLO])                176.0
#                           Equity(50119 [TRTN])                772.0
#                           Equity(50132 [APFH])               1059.0
#                           Equity(50138 [PI])                  254.0
#                           Equity(50143 [PTHN])               1000.0
#                           Equity(50181 [FHB])                1942.0
#                           Equity(50194 [MEDP])               1143.0
#                           Equity(50242 [DVMT])                195.0
#
# ...
#                           Equity(49655 [TEAM])              1890.0
#                           Equity(49666 [AGR])               1186.0
#                           Equity(49700 [FCE_A])              791.0
#                           Equity(49727 [GCP])               1325.0
#                           Equity(49736 [EDIT])               271.0
#                           Equity(49751 [AVXS])              2009.0
#                           Equity(49760 [WBT])               1324.0
#                           Equity(49877 [PNK])               2015.0
#                           Equity(49883 [LSXM_K])            1239.0
#                           Equity(49891 [MGP])               1352.0
#                           Equity(49908 [RRR])                942.0
#                           Equity(49925 [NGVT])              1757.0
#                           Equity(49959 [SITE])              1954.0
#                           Equity(50002 [COTV])              1712.0
#                           Equity(50003 [USFD])              1513.0
#                           Equity(50004 [GMS])               1870.0
#                           Equity(50040 [ATKR])              1061.0
#                           Equity(50049 [FTV])               1586.0
#                           Equity(50070 [HTZ])                  2.0
#                           Equity(50077 [TWLO])                31.0
#                           Equity(50119 [TRTN])              2046.0
#                           Equity(50132 [APFH])              2025.0
#                           Equity(50138 [PI])                1982.0
#                           Equity(50143 [PTHN])              1359.0
#                           Equity(50181 [FHB])                560.0
#                           Equity(50194 [MEDP])               146.0
#                           Equity(50242 [DVMT])              1610.0
#
#                                                   Return on Invest Capital  \
# 2017-01-03 00:00:00+00:00 Equity(2 [ARNC])                           707.0
#                           Equity(24 [AAPL])                         1714.0
#                           Equity(31 [ABAX])                         1797.0
#                           Equity(41 [ARCB])                          996.0
#                           Equity(52 [ABM])                           602.0
#                           Equity(53 [ABMD])                         1243.0
#                           Equity(62 [ABT])                           268.0
#                           Equity(64 [ABX])                          1101.0
#                           Equity(67 [ADSK])                          131.0
#                           Equity(76 [TAP])                           800.0
#                           Equity(84 [ACET])                          852.0
#                           Equity(110 [ACXM])                         653.0
#                           Equity(114 [ADBE])                        1502.0
#                           Equity(122 [ADI])                         1811.0
#                           Equity(128 [ADM])                          967.0
#                           Equity(154 [AEM])                          755.0
#                           Equity(161 [AEP])                          234.0
#                           Equity(166 [AES])                          871.0
#                           Equity(168 [AET])                         1109.0
#                           Equity(185 [AFL])                         1491.0
#                           Equity(197 [AGCO])                         618.0
#                           Equity(216 [HES])                          256.0
#                           Equity(239 [AIG])                         1140.0
#                           Equity(247 [AIN])                          834.0
#                           Equity(253 [AIR])                          806.0
#                           Equity(266 [AJG])                         1261.0
#                           Equity(270 [AKRX])                        1500.0
#                           Equity(289 [MATX])                        1408.0
#                           Equity(300 [ALK])                         1912.0
#                           Equity(301 [ALKS])                         163.0
# ...                                                                    ...
# 2017-06-01 00:00:00+00:00 Equity(49610 [SQ])                         216.0
#                           Equity(49615 [DLTH])                      2054.0
#                           Equity(49630 [CSRA])                       975.0
#                           Equity(49655 [TEAM])                       207.0
#                           Equity(49666 [AGR])                        969.0
#                           Equity(49700 [FCE_A])                      663.0
#                           Equity(49727 [GCP])                       1807.0
#                           Equity(49736 [EDIT])                        69.0
#                           Equity(49751 [AVXS])                        78.0
#                           Equity(49760 [WBT])                       1267.0
#                           Equity(49877 [PNK])                         89.0
#                           Equity(49883 [LSXM_K])                     740.0
#                           Equity(49891 [MGP])                        807.0
#                           Equity(49908 [RRR])                        609.0
#                           Equity(49925 [NGVT])                      1671.0
#                           Equity(49959 [SITE])                       261.0
#                           Equity(50002 [COTV])                      1248.0
#                           Equity(50003 [USFD])                       490.0
#                           Equity(50004 [GMS])                        848.0
#                           Equity(50040 [ATKR])                      1420.0
#                           Equity(50049 [FTV])                       1705.0
#                           Equity(50070 [HTZ])                        237.0
#                           Equity(50077 [TWLO])                       155.0
#                           Equity(50119 [TRTN])                       570.0
#                           Equity(50132 [APFH])                         NaN
#                           Equity(50138 [PI])                         235.0
#                           Equity(50143 [PTHN])                      1027.0
#                           Equity(50181 [FHB])                          NaN
#                           Equity(50194 [MEDP])                       797.0
#                           Equity(50242 [DVMT])                       200.0
#
#                                                   Trendline  Vol 3M  \
# 2017-01-03 00:00:00+00:00 Equity(2 [ARNC])            219.0  2001.0
#                           Equity(24 [AAPL])          1684.0    89.0
#                           Equity(31 [ABAX])          1198.0   990.0
#                           Equity(41 [ARCB])          1023.0  1589.0
#                           Equity(52 [ABM])           1495.0   731.0
#                           Equity(53 [ABMD])          1967.0  1343.0
#                           Equity(62 [ABT])            477.0   484.0
#                           Equity(64 [ABX])            896.0  1803.0
#                           Equity(67 [ADSK])          1837.0  1309.0
#                           Equity(76 [TAP])           1582.0   235.0
#                           Equity(84 [ACET])           221.0  1455.0
#                           Equity(110 [ACXM])         1127.0   887.0
#                           Equity(114 [ADBE])         1763.0   163.0
#                           Equity(122 [ADI])          1694.0   674.0
#                           Equity(128 [ADM])          1440.0  1025.0
#                           Equity(154 [AEM])          1568.0  1777.0
#                           Equity(161 [AEP])           611.0   284.0
#                           Equity(166 [AES])           638.0  1010.0
#                           Equity(168 [AET])          1615.0   667.0
#                           Equity(185 [AFL])          1530.0    54.0
#                           Equity(197 [AGCO])          993.0   364.0
#                           Equity(216 [HES])          1332.0  1576.0
#                           Equity(239 [AIG])          1373.0   178.0
#                           Equity(247 [AIN])          1376.0   581.0
#                           Equity(253 [AIR])          1534.0  1031.0
#                           Equity(266 [AJG])          1494.0    75.0
#                           Equity(270 [AKRX])          184.0  1880.0
#                           Equity(289 [MATX])          417.0  1676.0
#                           Equity(300 [ALK])           961.0   892.0
#                           Equity(301 [ALKS])         1576.0  1932.0
# ...                                                     ...     ...
# 2017-06-01 00:00:00+00:00 Equity(49610 [SQ])         1392.0  1477.0
#                           Equity(49615 [DLTH])        168.0  1811.0
#                           Equity(49630 [CSRA])       1153.0   799.0
#                           Equity(49655 [TEAM])       1074.0   621.0
#                           Equity(49666 [AGR])         568.0   137.0
#                           Equity(49700 [FCE_A])       481.0   223.0
#                           Equity(49727 [GCP])        1090.0  1834.0
#                           Equity(49736 [EDIT])        219.0  2044.0
#                           Equity(49751 [AVXS])       1990.0  1954.0
#                           Equity(49760 [WBT])         867.0   772.0
#                           Equity(49877 [PNK])        1373.0  1253.0
#                           Equity(49883 [LSXM_K])     1245.0   827.0
#                           Equity(49891 [MGP])         824.0   256.0
#                           Equity(49908 [RRR])         641.0   684.0
#                           Equity(49925 [NGVT])       1896.0  1148.0
#                           Equity(49959 [SITE])       1591.0  1166.0
#                           Equity(50002 [COTV])       1743.0  1259.0
#                           Equity(50003 [USFD])       1034.0   209.0
#                           Equity(50004 [GMS])        1565.0   918.0
#                           Equity(50040 [ATKR])          NaN  1645.0
#                           Equity(50049 [FTV])           NaN   139.0
#                           Equity(50070 [HTZ])           NaN  2042.0
#                           Equity(50077 [TWLO])          NaN  2022.0
#                           Equity(50119 [TRTN])          NaN  1950.0
#                           Equity(50132 [APFH])          NaN  1460.0
#                           Equity(50138 [PI])            NaN  1875.0
#                           Equity(50143 [PTHN])          NaN  2056.0
#                           Equity(50181 [FHB])           NaN   802.0
#                           Equity(50194 [MEDP])          NaN  2041.0
#                           Equity(50242 [DVMT])          NaN   387.0
#
#                                                   Working Capital to Assets
# 2017-01-03 00:00:00+00:00 Equity(2 [ARNC])                            794.0
#                           Equity(24 [AAPL])                           719.0
#                           Equity(31 [ABAX])                          1713.0
#                           Equity(41 [ARCB])                           786.0
#                           Equity(52 [ABM])                           1030.0
#                           Equity(53 [ABMD])                          1647.0
#                           Equity(62 [ABT])                            839.0
#                           Equity(64 [ABX])                            866.0
#                           Equity(67 [ADSK])                           946.0
#                           Equity(76 [TAP])                           1524.0
#                           Equity(84 [ACET])                          1583.0
#                           Equity(110 [ACXM])                          959.0
#                           Equity(114 [ADBE])                         1200.0
#                           Equity(122 [ADI])                          1615.0
#                           Equity(128 [ADM])                          1090.0
#                           Equity(154 [AEM])                           849.0
#                           Equity(161 [AEP])                           169.0
#                           Equity(166 [AES])                           531.0
#                           Equity(168 [AET])                           931.0
#                           Equity(185 [AFL])                             NaN
#                           Equity(197 [AGCO])                         1002.0
#                           Equity(216 [HES])                           630.0
#                           Equity(239 [AIG])                             NaN
#                           Equity(247 [AIN])                          1316.0
#                           Equity(253 [AIR])                          1452.0
#                           Equity(266 [AJG])                           219.0
#                           Equity(270 [AKRX])                         1232.0
#                           Equity(289 [MATX])                          370.0
#                           Equity(300 [ALK])                          1012.0
#                           Equity(301 [ALKS])                         1440.0
# ...                                                                     ...
# 2017-06-01 00:00:00+00:00 Equity(49610 [SQ])                         1615.0
#                           Equity(49615 [DLTH])                       1550.0
#                           Equity(49630 [CSRA])                        347.0
#                           Equity(49655 [TEAM])                       1110.0
#                           Equity(49666 [AGR])                         258.0
#                           Equity(49700 [FCE_A])                       478.0
#                           Equity(49727 [GCP])                        1221.0
#                           Equity(49736 [EDIT])                       1768.0
#                           Equity(49751 [AVXS])                       1763.0
#                           Equity(49760 [WBT])                         577.0
#                           Equity(49877 [PNK])                         232.0
#                           Equity(49883 [LSXM_K])                      102.0
#                           Equity(49891 [MGP])                         426.0
#                           Equity(49908 [RRR])                         299.0
#                           Equity(49925 [NGVT])                       1183.0
#                           Equity(49959 [SITE])                       1517.0
#                           Equity(50002 [COTV])                        521.0
#                           Equity(50003 [USFD])                        762.0
#                           Equity(50004 [GMS])                        1226.0
#                           Equity(50040 [ATKR])                       1317.0
#                           Equity(50049 [FTV])                         894.0
#                           Equity(50070 [HTZ])                         423.0
#                           Equity(50077 [TWLO])                       1692.0
#                           Equity(50119 [TRTN])                         66.0
#                           Equity(50132 [APFH])                       1024.0
#                           Equity(50138 [PI])                         1751.0
#                           Equity(50143 [PTHN])                        962.0
#                           Equity(50181 [FHB])                           NaN
#                           Equity(50194 [MEDP])                        225.0
#                           Equity(50242 [DVMT])                          6.0
#
# [215685 rows x 18 columns]

# %% [markdown]
# The target will be whether the stocks's return in future (5 days horizon) is among top 30 percent or bottom 30 percent

# %%
target=output['top_returns']*1.0-output['bottom_returns']*1.0
target
# Out:
# 2017-01-03 00:00:00+00:00  Equity(2 [ARNC])         -1.0
#                            Equity(24 [AAPL])         1.0
#                            Equity(31 [ABAX])         1.0
#                            Equity(41 [ARCB])         0.0
#                            Equity(52 [ABM])          1.0
#                            Equity(53 [ABMD])         1.0
#                            Equity(62 [ABT])          0.0
#                            Equity(64 [ABX])          1.0
#                            Equity(67 [ADSK])         1.0
#                            Equity(76 [TAP])          1.0
#                            Equity(84 [ACET])         1.0
#                            Equity(110 [ACXM])        1.0
#                            Equity(114 [ADBE])        0.0
#                            Equity(122 [ADI])         0.0
#                            Equity(128 [ADM])         0.0
#                            Equity(154 [AEM])         1.0
#                            Equity(161 [AEP])         0.0
#                            Equity(166 [AES])        -1.0
#                            Equity(168 [AET])         0.0
#                            Equity(185 [AFL])         0.0
#                            Equity(197 [AGCO])        1.0
#                            Equity(216 [HES])         0.0
#                            Equity(239 [AIG])        -1.0
#                            Equity(247 [AIN])         0.0
#                            Equity(253 [AIR])         0.0
#                            Equity(266 [AJG])         0.0
#                            Equity(270 [AKRX])        1.0
#                            Equity(289 [MATX])       -1.0
#                            Equity(300 [ALK])         0.0
#                            Equity(301 [ALKS])       -1.0
#                                                     ...
# 2017-06-01 00:00:00+00:00  Equity(49610 [SQ])        1.0
#                            Equity(49615 [DLTH])     -1.0
#                            Equity(49630 [CSRA])      1.0
#                            Equity(49655 [TEAM])      0.0
#                            Equity(49666 [AGR])       1.0
#                            Equity(49700 [FCE_A])     0.0
#                            Equity(49727 [GCP])       0.0
#                            Equity(49736 [EDIT])     -1.0
#                            Equity(49751 [AVXS])     -1.0
#                            Equity(49760 [WBT])      -1.0
#                            Equity(49877 [PNK])       0.0
#                            Equity(49883 [LSXM_K])    1.0
#                            Equity(49891 [MGP])       0.0
#                            Equity(49908 [RRR])       0.0
#                            Equity(49925 [NGVT])      0.0
#                            Equity(49959 [SITE])      1.0
#                            Equity(50002 [COTV])     -1.0
#                            Equity(50003 [USFD])      1.0
#                            Equity(50004 [GMS])      -1.0
#                            Equity(50040 [ATKR])      0.0
#                            Equity(50049 [FTV])       0.0
#                            Equity(50070 [HTZ])       1.0
#                            Equity(50077 [TWLO])     -1.0
#                            Equity(50119 [TRTN])     -1.0
#                            Equity(50132 [APFH])      0.0
#                            Equity(50138 [PI])        1.0
#                            Equity(50143 [PTHN])      0.0
#                            Equity(50181 [FHB])      -1.0
#                            Equity(50194 [MEDP])      1.0
#                            Equity(50242 [DVMT])      1.0
# dtype: float64

# %%
asset_list=feature.index.levels[1]
len(asset_list)
# Out:
# 2191

# %%
X=[]
for asset in asset_list:
    tempx=np.array(feature.xs(asset,level=1))
    tempy=np.array(target.xs(asset,level=1))
    tempy=tempy.reshape((len(tempy),1))
    # shift the return value by n_fwd_days and select only those that are in top or bottom group
    tempX=np.concatenate((tempx[:-n_fwd_days],tempy[n_fwd_days:]),axis=1)
    tempX=tempX[tempX[:,-1]!=0]
    if len(X)==0:
        X=tempX
    else:
        X=np.concatenate((X,tempX))

# %%
X.shape
# Out:
# (122823, 19)

# %% [markdown]
# final data preprocessing

# %%
X_p=preprocessing.Imputer().fit_transform(X) #fill nan
X_p=preprocessing.MinMaxScaler().fit_transform(X_p) # normalize data

# %% [markdown]
# # Trainning/testing model
#
# shuffle the data and separate into training and test group

# %%
X_p=np.random.permutation(X_p)

# %%
X_train=X_p[:int(len(X)*0.7)]
X_test=X_p[int(len(X)*0.7):]

# %%
clf = ensemble.GradientBoostingClassifier(n_estimators=150)

# %%
clf.fit(X_train[:,:18],X_train[:,18])
# Out:
# GradientBoostingClassifier(init=None, learning_rate=0.1, loss='deviance',
#               max_depth=3, max_features=None, max_leaf_nodes=None,
#               min_samples_leaf=1, min_samples_split=2,
#               min_weight_fraction_leaf=0.0, n_estimators=150,
#               random_state=None, subsample=1.0, verbose=0,
#               warm_start=False)

# %% [markdown]
# in sample prediction accuracy

# %%
clf.score(X_train[:,:18],X_train[:,18])
# Out:
# 0.59237461617195497

# %% [markdown]
# out sample prediction accuracy

# %%
clf.score(X_test[:,:18],X_test[:,18])
# Out:
# 0.57266534588976037

# %% [markdown]
# If we make random guess, by central limit theorem we will have an acuracy 0.5 with standard deviation $\sqrt{0.5*0.5/36847}=0.0026$. So this null hypothesis can be rejected, and there is "something" in this prediction
#
# Now we look at the feature importance

# %%
feature_importances = pd.Series(clf.feature_importances_, index=feature.columns)
ax = feature_importances.plot(kind='bar')
ax.set(ylabel='Importance (Gini Coefficient)', title='Feature importances');

# %% [markdown]
# Considering these data are actually time series, it might make more sense to allocate the trainning and test data according to time

# %%
X=[]
for asset in asset_list:
    tempx=np.array(feature.xs(asset,level=1))
    tempy=np.array(target.xs(asset,level=1))
    tempy=tempy.reshape((len(tempy),1))
    #create an additional column indicating the time of the data
    timelabel=range(len(tempx)-n_fwd_days)
    timelabel=np.array(timelabel).reshape((len(timelabel),1))
    # shift the return value by n_fwd_days and select only those that are in top or bottom group
    tempX=np.concatenate((tempx[:-n_fwd_days],tempy[n_fwd_days:],timelabel),axis=1)
    tempX=tempX[tempX[:,-2]!=0]
    if len(X)==0:
        X=tempX
    else:
        X=np.concatenate((X,tempX))

# %%
X.shape
# Out:
# (122823, 20)

# %%
X_p=preprocessing.Imputer().fit_transform(X)
X_p=preprocessing.MinMaxScaler().fit_transform(X_p)

# %% [markdown]
# We determine the train and test data according to the value int time columns, note that this column was already normalized to value 0 to 1 by previous function

# %%
X_train=X_p[X_p[:,-1]<=0.6]
X_test=X_p[X_p[:,-1]>0.6]

# %%
len(X_train)
# Out:
# 75153

# %%
clf = ensemble.GradientBoostingClassifier(n_estimators=150)

# %%
clf.fit(X_train[:,:18],X_train[:,18])
# Out:
# GradientBoostingClassifier(init=None, learning_rate=0.1, loss='deviance',
#               max_depth=3, max_features=None, max_leaf_nodes=None,
#               min_samples_leaf=1, min_samples_split=2,
#               min_weight_fraction_leaf=0.0, n_estimators=150,
#               random_state=None, subsample=1.0, verbose=0,
#               warm_start=False)

# %%
clf.score(X_train[:,:18],X_train[:,18])
# Out:
# 0.6065093875161337

# %% [markdown]
# The out sample prediction is less impressive but still significant

# %%
clf.score(X_test[:,:18],X_test[:,18])
# Out:
# 0.52662051604782878

# %% [markdown]
# The feature importances changes a bit comparing to the previous model

# %%
feature_importances = pd.Series(clf.feature_importances_, index=feature.columns)
ax = feature_importances.plot(kind='bar')
ax.set(ylabel='Importance (Gini Coefficient)', title='Feature importances');

# %%
clf = ensemble.RandomForestClassifier(n_estimators=200,max_leaf_nodes=20)

# %%
clf.fit(X_train[:,:18],X_train[:,18])
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=20,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=200, n_jobs=1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)

# %%
clf.score(X_train[:,:18],X_train[:,18])
# Out:
# 0.57083549558899849

# %%
clf.score(X_test[:,:18],X_test[:,18])
# Out:
# 0.52542479546884835
